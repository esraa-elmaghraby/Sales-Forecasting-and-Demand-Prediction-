# %%
# !pip install dask

# %%
import dask.dataframe as dd
df = dd.read_csv('C:/Users/Royaa/Downloads/archive (2)/train.csv')
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 0   0  2013-01-01         25    103665         7.0          NaN
# 1   1  2013-01-01         25    105574         1.0          NaN
# 2   2  2013-01-01         25    105575         2.0          NaN
# 3   3  2013-01-01         25    108079         1.0          NaN
# 4   4  2013-01-01         25    108701         1.0          NaN

# %%
import pandas as pd
df = pd.read_csv( 'C:/Users/Royaa/Downloads/archive (2)/train.csv', nrows=500000)
df
# Out:
#             id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 0            0  2013-01-01         25    103665         7.0          NaN
# 1            1  2013-01-01         25    105574         1.0          NaN
# 2            2  2013-01-01         25    105575         2.0          NaN
# 3            3  2013-01-01         25    108079         1.0          NaN
# 4            4  2013-01-01         25    108701         1.0          NaN
# ...        ...         ...        ...       ...         ...          ...
# 499995  499995  2013-01-14         16    716241         6.0          NaN
# 499996  499996  2013-01-14         16    716242         5.0          NaN
# 499997  499997  2013-01-14         16    716245         2.0          NaN
# 499998  499998  2013-01-14         16    716250         4.0          NaN
# 499999  499999  2013-01-14         16    723184         1.0          NaN
#
# [500000 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# store_nbr           0
# item_nbr            0
# unit_sales          0
# onpromotion    500000
# dtype: int64

# %%
file_path = 'C:/Users/Royaa/Downloads/archive (2)/train.csv'

chunksize = 10000  
for chunk in pd.read_csv(file_path, chunksize=chunksize):
    print(chunk.head())
# Out:
#    id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 0   0  2013-01-01         25    103665         7.0          NaN
# 1   1  2013-01-01         25    105574         1.0          NaN
# 2   2  2013-01-01         25    105575         2.0          NaN
# 3   3  2013-01-01         25    108079         1.0          NaN
# 4   4  2013-01-01         25    108701         1.0          NaN
#           id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 10000  10000  2013-01-02          9    723184        63.0          NaN
# 10001  10001  2013-01-02          9    723210         7.0          NaN
# 10002  10002  2013-01-02          9    724003         8.0          NaN
# 10003  10003  2013-01-02          9    724359        10.0          NaN
# 10004  10004  2013-01-02          9    724360         4.0          NaN
#           id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 20000  20000  2013-01-02         25    319094         1.0          NaN
# ...

# %%
df['onpromotion'] = df['onpromotion'].astype('boolean')  
df['onpromotion'] = df['onpromotion'].fillna(False)

# %%
df['onpromotion'].isnull().sum()
# Out:
# 0

# %%
df.to_csv('C:/Users/Royaa/Downloads/archive (2)/train_cleaned.csv', index=False)
