# %% [markdown]
# # Data Cleaning

# %%
from sklearn.preprocessing import LabelEncoder 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## test.csv

# %%
test= pd.read_csv('Data/test.csv')

# %%
test.head(10)
# Out:
#           id        date  store_nbr  item_nbr  onpromotion
# 0  125497040  2017-08-16          1     96995        False
# 1  125497041  2017-08-16          1     99197        False
# 2  125497042  2017-08-16          1    103501        False
# 3  125497043  2017-08-16          1    103520        False
# 4  125497044  2017-08-16          1    103665        False
# 5  125497045  2017-08-16          1    105574        False
# 6  125497046  2017-08-16          1    105575        False
# 7  125497047  2017-08-16          1    105576        False
# 8  125497048  2017-08-16          1    105577        False
# 9  125497049  2017-08-16          1    105693        False

# %%
test.shape
# Out:
# (3370464, 5)

# %%
test.dtypes
# Out:
# id              int64
# date           object
# store_nbr       int64
# item_nbr        int64
# onpromotion      bool
# dtype: object

# %%
test['onpromotion'] = test['onpromotion'].astype(int)
test['onpromotion']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 3370459    0
# 3370460    0
# 3370461    0
# 3370462    0
# 3370463    0
# Name: onpromotion, Length: 3370464, dtype: int32

# %%
test['date']=pd.to_datetime(test['date'] , format= '%Y-%m-%d')
test['date']
# Out:
# 0         2017-08-16
# 1         2017-08-16
# 2         2017-08-16
# 3         2017-08-16
# 4         2017-08-16
#              ...
# 3370459   2017-08-31
# 3370460   2017-08-31
# 3370461   2017-08-31
# 3370462   2017-08-31
# 3370463   2017-08-31
# Name: date, Length: 3370464, dtype: datetime64[ns]

# %%
print(test.isnull().sum())
# Out:
# id             0
# date           0
# store_nbr      0
# item_nbr       0
# onpromotion    0
# dtype: int64

# %%
duplicates = test.duplicated().sum()
duplicates
# Out:
# 0

# %% [markdown]
# ## train.csv

# %%
dtypes = {
    "id": "int32",
    "store_nbr": "int16",
    "item_nbr": "int32",
    "unit_sales": "float32",
    "onpromotion": "category"
}
train = pd.read_csv('Data/train.csv',dtype=dtypes)

# %%
train.head(10)
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion
# 0   0  2013-01-01         25    103665         7.0         NaN
# 1   1  2013-01-01         25    105574         1.0         NaN
# 2   2  2013-01-01         25    105575         2.0         NaN
# 3   3  2013-01-01         25    108079         1.0         NaN
# 4   4  2013-01-01         25    108701         1.0         NaN
# 5   5  2013-01-01         25    108786         3.0         NaN
# 6   6  2013-01-01         25    108797         1.0         NaN
# 7   7  2013-01-01         25    108952         1.0         NaN
# 8   8  2013-01-01         25    111397        13.0         NaN
# 9   9  2013-01-01         25    114790         3.0         NaN

# %%
train.shape
# Out:
# (125497040, 6)

# %%
print(train.isnull().sum())
# Out:
# id                    0
# date                  0
# store_nbr             0
# item_nbr              0
# unit_sales            0
# onpromotion    21657651
# dtype: int64

# %%
train['onpromotion'].value_counts()
# Out:
# onpromotion
# False    96028767
# True      7810622
# Name: count, dtype: int64

# %%
train["onpromotion"] = train["onpromotion"].astype(str)
train["onpromotion"] = train["onpromotion"].replace("nan", "False") 
train["onpromotion"] = train["onpromotion"].map({"False": 0, "True": 1}).astype("int32")
train['onpromotion']
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#             ..
# 125497035    0
# 125497036    1
# 125497037    0
# 125497038    1
# 125497039    0
# Name: onpromotion, Length: 125497040, dtype: int32

# %%
print(train.isnull().sum())
# Out:
# id             0
# date           0
# store_nbr      0
# item_nbr       0
# unit_sales     0
# onpromotion    0
# dtype: int64

# %%
train.dtypes
# Out:
# id               int32
# date            object
# store_nbr        int16
# item_nbr         int32
# unit_sales     float32
# onpromotion      int32
# dtype: object

# %%
train['date']=pd.to_datetime(train['date'] , format= '%Y-%m-%d')
train['date']
# Out:
# 0           2013-01-01
# 1           2013-01-01
# 2           2013-01-01
# 3           2013-01-01
# 4           2013-01-01
#                ...
# 125497035   2017-08-15
# 125497036   2017-08-15
# 125497037   2017-08-15
# 125497038   2017-08-15
# 125497039   2017-08-15
# Name: date, Length: 125497040, dtype: datetime64[ns]

# %%
train_duplicates = train.duplicated().sum()
train_duplicates
# Out:
# 0

# %%
Q1=train['unit_sales'].quantile(0.25)
Q3=train['unit_sales'].quantile(0.75)
IQR=Q3-Q1
lower_bound= Q1 - 1.5 * IQR
upper_bound= Q3 + 1.5 * IQR
outliers = train[(train['unit_sales']< lower_bound) | (train['unit_sales']> upper_bound)]
outliers
# Out:
#                   id       date  store_nbr  item_nbr  unit_sales  onpromotion
# 35                35 2013-01-01         25    159156   29.903999            0
# 64                64 2013-01-01         25    215352   46.000000            0
# 68                68 2013-01-01         25    219150   21.000000            0
# 79                79 2013-01-01         25    257847   90.000000            0
# 113              113 2013-01-01         25    311994   22.589001            0
# ...              ...        ...        ...       ...         ...          ...
# 125497020  125497020 2017-08-15         54   2061033   23.000000            1
# 125497025  125497025 2017-08-15         54   2081064   49.000000            0
# 125497027  125497027 2017-08-15         54   2081161   41.000000            0
# 125497037  125497037 2017-08-15         54   2110456  192.000000            0
# 125497038  125497038 2017-08-15         54   2113914  198.000000            1
#
# [11497596 rows x 6 columns]

# %%
train["unit_sales"] = train["unit_sales"].clip(lower_bound, upper_bound)

# %%
# time based features
train['year'] = train['date'].dt.year
train['month'] = train['date'].dt.month
train['day'] = train['date'].dt.day
train['is_weekend'] = train['date'].dt.dayofweek >= 5

# %%
train.head()
# Out:
#    id       date  store_nbr  item_nbr  unit_sales  onpromotion  year  month  \
# 0   0 2013-01-01         25    103665         7.0            0  2013      1
# 1   1 2013-01-01         25    105574         1.0            0  2013      1
# 2   2 2013-01-01         25    105575         2.0            0  2013      1
# 3   3 2013-01-01         25    108079         1.0            0  2013      1
# 4   4 2013-01-01         25    108701         1.0            0  2013      1
#
#    day  is_weekend
# 0    1       False
# 1    1       False
# 2    1       False
# 3    1       False
# 4    1       False

# %%
train['lag_7'] = train['unit_sales'].shift(7)

# %%
train['lag_30'] = train['unit_sales'].shift(30)
train['lag_30'] = train['lag_30'].fillna(0)
train.head(50)
# Out:
#     id       date  store_nbr  item_nbr  unit_sales  onpromotion  year  month  \
# 0    0 2013-01-01         25    103665         7.0            0  2013      1
# 1    1 2013-01-01         25    105574         1.0            0  2013      1
# 2    2 2013-01-01         25    105575         2.0            0  2013      1
# 3    3 2013-01-01         25    108079         1.0            0  2013      1
# 4    4 2013-01-01         25    108701         1.0            0  2013      1
# 5    5 2013-01-01         25    108786         3.0            0  2013      1
# 6    6 2013-01-01         25    108797         1.0            0  2013      1
# 7    7 2013-01-01         25    108952         1.0            0  2013      1
# 8    8 2013-01-01         25    111397        13.0            0  2013      1
# 9    9 2013-01-01         25    114790         3.0            0  2013      1
# 10  10 2013-01-01         25    114800         1.0            0  2013      1
# 11  11 2013-01-01         25    115267         1.0            0  2013      1
# 12  12 2013-01-01         25    115611         1.0            0  2013      1
# 13  13 2013-01-01         25    115693         1.0            0  2013      1
# 14  14 2013-01-01         25    115720         5.0            0  2013      1
# 15  15 2013-01-01         25    115850         1.0            0  2013      1
# 16  16 2013-01-01         25    115891         6.0            0  2013      1
# 17  17 2013-01-01         25    115892        10.0            0  2013      1
# 18  18 2013-01-01         25    115894         5.0            0  2013      1
# 19  19 2013-01-01         25    119024         1.0            0  2013      1
# 20  20 2013-01-01         25    119026         1.0            0  2013      1
# 21  21 2013-01-01         25    119141         1.0            0  2013      1
# 22  22 2013-01-01         25    119187         1.0            0  2013      1
# 23  23 2013-01-01         25    119624         4.0            0  2013      1
# 24  24 2013-01-01         25    123927         1.0            0  2013      1
# 25  25 2013-01-01         25    129635        11.0            0  2013      1
# 26  26 2013-01-01         25    153239         3.0            0  2013      1
# 27  27 2013-01-01         25    153267         9.0            0  2013      1
# 28  28 2013-01-01         25    153395         7.0            0  2013      1
# 29  29 2013-01-01         25    155607         2.0            0  2013      1
# 30  30 2013-01-01         25    158680         1.0            0  2013      1
# 31  31 2013-01-01         25    158788         4.0            0  2013      1
# 32  32 2013-01-01         25    158842         9.0            0  2013      1
# 33  33 2013-01-01         25    158875         1.0            0  2013      1
# 34  34 2013-01-01         25    158956         5.0            0  2013      1
# 35  35 2013-01-01         25    159156        19.5            0  2013      1
# 36  36 2013-01-01         25    162066         2.0            0  2013      1
# 37  37 2013-01-01         25    164036         1.0            0  2013      1
# 38  38 2013-01-01         25    164088         3.0            0  2013      1
# 39  39 2013-01-01         25    165550        10.0            0  2013      1
# 40  40 2013-01-01         25    165551         1.0            0  2013      1
# 41  41 2013-01-01         25    165553         9.0            0  2013      1
# 42  42 2013-01-01         25    165594         4.0            0  2013      1
# 43  43 2013-01-01         25    165704         4.0            0  2013      1
# 44  44 2013-01-01         25    165705        15.0            0  2013      1
# 45  45 2013-01-01         25    165718         2.0            0  2013      1
# 46  46 2013-01-01         25    165988         1.0            0  2013      1
# 47  47 2013-01-01         25    168927         9.0            0  2013      1
# 48  48 2013-01-01         25    169104         1.0            0  2013      1
# 49  49 2013-01-01         25    172184         2.0            0  2013      1
#
#     day  is_weekend  lag_7  lag_30
# 0     1       False    0.0     0.0
# 1     1       False    0.0     0.0
# 2     1       False    0.0     0.0
# 3     1       False    0.0     0.0
# 4     1       False    0.0     0.0
# 5     1       False    0.0     0.0
# 6     1       False    0.0     0.0
# 7     1       False    7.0     0.0
# 8     1       False    1.0     0.0
# 9     1       False    2.0     0.0
# 10    1       False    1.0     0.0
# 11    1       False    1.0     0.0
# 12    1       False    3.0     0.0
# 13    1       False    1.0     0.0
# 14    1       False    1.0     0.0
# 15    1       False   13.0     0.0
# 16    1       False    3.0     0.0
# 17    1       False    1.0     0.0
# 18    1       False    1.0     0.0
# 19    1       False    1.0     0.0
# 20    1       False    1.0     0.0
# 21    1       False    5.0     0.0
# 22    1       False    1.0     0.0
# 23    1       False    6.0     0.0
# 24    1       False   10.0     0.0
# 25    1       False    5.0     0.0
# 26    1       False    1.0     0.0
# 27    1       False    1.0     0.0
# 28    1       False    1.0     0.0
# 29    1       False    1.0     0.0
# 30    1       False    4.0     7.0
# 31    1       False    1.0     1.0
# 32    1       False   11.0     2.0
# 33    1       False    3.0     1.0
# 34    1       False    9.0     1.0
# 35    1       False    7.0     3.0
# 36    1       False    2.0     1.0
# 37    1       False    1.0     1.0
# 38    1       False    4.0    13.0
# 39    1       False    9.0     3.0
# 40    1       False    1.0     1.0
# 41    1       False    5.0     1.0
# 42    1       False   19.5     1.0
# 43    1       False    2.0     1.0
# 44    1       False    1.0     5.0
# 45    1       False    3.0     1.0
# 46    1       False   10.0     6.0
# 47    1       False    1.0    10.0
# 48    1       False    9.0     5.0
# 49    1       False    4.0     1.0

# %%
train['lag_7'] = train['lag_7'].fillna(0)
train.head(50)
# Out:
#     id       date  store_nbr  item_nbr  unit_sales  onpromotion  year  month  \
# 0    0 2013-01-01         25    103665         7.0            0  2013      1
# 1    1 2013-01-01         25    105574         1.0            0  2013      1
# 2    2 2013-01-01         25    105575         2.0            0  2013      1
# 3    3 2013-01-01         25    108079         1.0            0  2013      1
# 4    4 2013-01-01         25    108701         1.0            0  2013      1
# 5    5 2013-01-01         25    108786         3.0            0  2013      1
# 6    6 2013-01-01         25    108797         1.0            0  2013      1
# 7    7 2013-01-01         25    108952         1.0            0  2013      1
# 8    8 2013-01-01         25    111397        13.0            0  2013      1
# 9    9 2013-01-01         25    114790         3.0            0  2013      1
# 10  10 2013-01-01         25    114800         1.0            0  2013      1
# 11  11 2013-01-01         25    115267         1.0            0  2013      1
# 12  12 2013-01-01         25    115611         1.0            0  2013      1
# 13  13 2013-01-01         25    115693         1.0            0  2013      1
# 14  14 2013-01-01         25    115720         5.0            0  2013      1
# 15  15 2013-01-01         25    115850         1.0            0  2013      1
# 16  16 2013-01-01         25    115891         6.0            0  2013      1
# 17  17 2013-01-01         25    115892        10.0            0  2013      1
# 18  18 2013-01-01         25    115894         5.0            0  2013      1
# 19  19 2013-01-01         25    119024         1.0            0  2013      1
# 20  20 2013-01-01         25    119026         1.0            0  2013      1
# 21  21 2013-01-01         25    119141         1.0            0  2013      1
# 22  22 2013-01-01         25    119187         1.0            0  2013      1
# 23  23 2013-01-01         25    119624         4.0            0  2013      1
# 24  24 2013-01-01         25    123927         1.0            0  2013      1
# 25  25 2013-01-01         25    129635        11.0            0  2013      1
# 26  26 2013-01-01         25    153239         3.0            0  2013      1
# 27  27 2013-01-01         25    153267         9.0            0  2013      1
# 28  28 2013-01-01         25    153395         7.0            0  2013      1
# 29  29 2013-01-01         25    155607         2.0            0  2013      1
# 30  30 2013-01-01         25    158680         1.0            0  2013      1
# 31  31 2013-01-01         25    158788         4.0            0  2013      1
# 32  32 2013-01-01         25    158842         9.0            0  2013      1
# 33  33 2013-01-01         25    158875         1.0            0  2013      1
# 34  34 2013-01-01         25    158956         5.0            0  2013      1
# 35  35 2013-01-01         25    159156        19.5            0  2013      1
# 36  36 2013-01-01         25    162066         2.0            0  2013      1
# 37  37 2013-01-01         25    164036         1.0            0  2013      1
# 38  38 2013-01-01         25    164088         3.0            0  2013      1
# 39  39 2013-01-01         25    165550        10.0            0  2013      1
# 40  40 2013-01-01         25    165551         1.0            0  2013      1
# 41  41 2013-01-01         25    165553         9.0            0  2013      1
# 42  42 2013-01-01         25    165594         4.0            0  2013      1
# 43  43 2013-01-01         25    165704         4.0            0  2013      1
# 44  44 2013-01-01         25    165705        15.0            0  2013      1
# 45  45 2013-01-01         25    165718         2.0            0  2013      1
# 46  46 2013-01-01         25    165988         1.0            0  2013      1
# 47  47 2013-01-01         25    168927         9.0            0  2013      1
# 48  48 2013-01-01         25    169104         1.0            0  2013      1
# 49  49 2013-01-01         25    172184         2.0            0  2013      1
#
#     day  is_weekend  lag_7
# 0     1       False    0.0
# 1     1       False    0.0
# 2     1       False    0.0
# 3     1       False    0.0
# 4     1       False    0.0
# 5     1       False    0.0
# 6     1       False    0.0
# 7     1       False    7.0
# 8     1       False    1.0
# 9     1       False    2.0
# 10    1       False    1.0
# 11    1       False    1.0
# 12    1       False    3.0
# 13    1       False    1.0
# 14    1       False    1.0
# 15    1       False   13.0
# 16    1       False    3.0
# 17    1       False    1.0
# 18    1       False    1.0
# 19    1       False    1.0
# 20    1       False    1.0
# 21    1       False    5.0
# 22    1       False    1.0
# 23    1       False    6.0
# 24    1       False   10.0
# 25    1       False    5.0
# 26    1       False    1.0
# 27    1       False    1.0
# 28    1       False    1.0
# 29    1       False    1.0
# 30    1       False    4.0
# 31    1       False    1.0
# 32    1       False   11.0
# 33    1       False    3.0
# 34    1       False    9.0
# 35    1       False    7.0
# 36    1       False    2.0
# 37    1       False    1.0
# 38    1       False    4.0
# 39    1       False    9.0
# 40    1       False    1.0
# 41    1       False    5.0
# 42    1       False   19.5
# 43    1       False    2.0
# 44    1       False    1.0
# 45    1       False    3.0
# 46    1       False   10.0
# 47    1       False    1.0
# 48    1       False    9.0
# 49    1       False    4.0

# %%
train.shape
# Out:
# (125497040, 12)

# %% [markdown]
# ## transactions.csv

# %%
transactions=pd.read_csv('Data/transactions.csv')

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.shape
# Out:
# (83488, 3)

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %%
transactions['date']=pd.to_datetime(transactions['date'] , format= '%Y-%m-%d')

# %%
transactions_dup=transactions.duplicated().sum()
transactions_dup
# Out:
# 0

# %%
print(transactions.isnull().sum())
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
Q1=transactions['transactions'].quantile(0.25)
Q3=transactions['transactions'].quantile(0.75)
IQR=Q3-Q1
lower_bound= Q1 - 1.5 * IQR
upper_bound= Q3 + 1.5 * IQR
outliers = transactions[(transactions['transactions']< lower_bound) | (transactions['transactions']> upper_bound)]
outliers
# Out:
#             date  store_nbr  transactions
# 38    2013-01-02         44          4821
# 39    2013-01-02         45          4208
# 40    2013-01-02         46          4886
# 41    2013-01-02         47          4161
# 87    2013-01-03         47          3660
# ...          ...        ...           ...
# 83372 2017-08-13         47          3741
# 83423 2017-08-14         44          4039
# 83424 2017-08-14         45          3743
# 83477 2017-08-15         44          3815
# 83478 2017-08-15         45          3685
#
# [4583 rows x 3 columns]

# %%
transactions['transactions'] = transactions['transactions'].clip(lower_bound, upper_bound)

# %%
transactions['avg_transaction_per_store'] = transactions.groupby("store_nbr")["transactions"].transform("mean")
transactions.head()
# Out:
#         date  store_nbr  transactions  avg_transaction_per_store
# 0 2013-01-01         25         770.0                 941.400619
# 1 2013-01-02          1        2111.0                1523.844272
# 2 2013-01-02          2        2358.0                1919.507752
# 3 2013-01-02          3        3487.0                3155.176313
# 4 2013-01-02          4        1922.0                1502.987470

# %% [markdown]
# ## stores.csv

# %%
stores=pd.read_csv('Data/stores.csv')
stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
stores.shape
# Out:
# (54, 5)

# %%
print(stores.isnull().sum())
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %%
stores_duplicates=stores.duplicated().sum()
stores_duplicates
# Out:
# 0

# %%
stores['city'].value_counts()
# Out:
# city
# Quito            18
# Guayaquil         8
# Cuenca            3
# Santo Domingo     3
# Manta             2
# Latacunga         2
# Machala           2
# Ambato            2
# Quevedo           1
# Esmeraldas        1
# Loja              1
# Libertad          1
# Playas            1
# Daule             1
# Babahoyo          1
# Salinas           1
# Puyo              1
# Guaranda          1
# Ibarra            1
# Riobamba          1
# Cayambe           1
# El Carmen         1
# Name: count, dtype: int64

# %%
stores['city'] = LabelEncoder().fit_transform(stores['city'])
stores['state'] = LabelEncoder().fit_transform(stores['state'])
stores['type'] = LabelEncoder().fit_transform(stores['type'])
stores.head()
# Out:
#    store_nbr  city  state  type  cluster
# 0          1    18     12     3       13
# 1          2    18     12     3       13
# 2          3    18     12     3        8
# 3          4    18     12     3        9
# 4          5    21     14     3        4

# %%
stores.dtypes
# Out:
# store_nbr    int64
# city         int32
# state        int32
# type         int32
# cluster      int64
# dtype: object

# %% [markdown]
# ## oil.csv

# %%
oil=pd.read_csv('Data/oil.csv')
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.shape
# Out:
# (1218, 2)

# %%
print(oil.isnull().sum())
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
oil['dcoilwtico'] = oil['dcoilwtico'].bfill() # backward fill

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01       93.14
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
oil['date']=pd.to_datetime(oil['date'] , format= '%Y-%m-%d')

# %%
oil['oil_price_change']=oil['dcoilwtico'].pct_change()

# %%
oil.head()
# Out:
#         date  dcoilwtico  oil_price_change
# 0 2013-01-01       93.14               NaN
# 1 2013-01-02       93.14          0.000000
# 2 2013-01-03       92.97         -0.001825
# 3 2013-01-04       93.12          0.001613
# 4 2013-01-07       93.20          0.000859

# %%
print(oil.isnull().sum())
# Out:
# date                0
# dcoilwtico          0
# oil_price_change    1
# dtype: int64

# %%
oil=oil.dropna()

# %%
oil.head()
# Out:
#         date  dcoilwtico  oil_price_change
# 1 2013-01-02       93.14          0.000000
# 2 2013-01-03       92.97         -0.001825
# 3 2013-01-04       93.12          0.001613
# 4 2013-01-07       93.20          0.000859
# 5 2013-01-08       93.21          0.000107

# %% [markdown]
# ## items.csv

# %%
items=pd.read_csv('Data/items.csv')
items.head()
# Out:
#    item_nbr        family  class  perishable
# 0     96995     GROCERY I   1093           0
# 1     99197     GROCERY I   1067           0
# 2    103501      CLEANING   3008           0
# 3    103520     GROCERY I   1028           0
# 4    103665  BREAD/BAKERY   2712           1

# %%
items.shape
# Out:
# (4100, 4)

# %%
items.dtypes
# Out:
# item_nbr       int64
# family        object
# class          int64
# perishable     int64
# dtype: object

# %%
print(items.isnull().sum())
# Out:
# item_nbr      0
# family        0
# class         0
# perishable    0
# dtype: int64

# %%
items_duplicates=items.duplicated().sum()
items_duplicates
# Out:
# 0

# %%
items['family'] = LabelEncoder().fit_transform(items['family'])

# %%
items.head()
# Out:
#    item_nbr  family  class  perishable
# 0     96995      12   1093           0
# 1     99197      12   1067           0
# 2    103501       7   3008           0
# 3    103520      12   1028           0
# 4    103665       5   2712           1

# %% [markdown]
# ## holidays_events.csv

# %%
holidays_events=pd.read_csv('Data/holidays_events.csv')

# %%
holidays_events.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
holidays_events.shape
# Out:
# (350, 6)

# %%
holidays_events['type'].value_counts()
# Out:
# type
# Holiday       221
# Event          56
# Additional     51
# Transfer       12
# Bridge          5
# Work Day        5
# Name: count, dtype: int64

# %%
holidays_events['locale_name'].value_counts()
# Out:
# locale_name
# Ecuador                           174
# Quito                              13
# Riobamba                           12
# Guaranda                           12
# Latacunga                          12
# Ambato                             12
# Guayaquil                          11
# Cuenca                              7
# Ibarra                              7
# Salinas                             6
# Loja                                6
# Santa Elena                         6
# Santo Domingo de los Tsachilas      6
# Quevedo                             6
# Manta                               6
# Esmeraldas                          6
# Cotopaxi                            6
# El Carmen                           6
# Santo Domingo                       6
# Machala                             6
# Imbabura                            6
# Puyo                                6
# Libertad                            6
# Cayambe                             6
# Name: count, dtype: int64

# %%
holidays_events['type'] = LabelEncoder().fit_transform(holidays_events['type'])
holidays_events['locale'] = LabelEncoder().fit_transform(holidays_events['locale'])
holidays_events['locale_name'] = LabelEncoder().fit_transform(holidays_events['locale_name'])

# %%
holidays_events['transferred']=holidays_events['transferred'].astype(int)

# %%
holidays_events['description'].value_counts()
# Out:
# description
# Carnaval                              10
# Fundacion de Cuenca                    7
# Fundacion de Ibarra                    7
# Fundacion de Quito                     6
# Provincializacion de Santo Domingo     6
#                                       ..
# Terremoto Manabi+8                     1
# Recupero puente Navidad                1
# Terremoto Manabi+10                    1
# Terremoto Manabi+11                    1
# Traslado Fundacion de Quito            1
# Name: count, Length: 103, dtype: int64

# %%
holidays_events.drop(columns=['description'], inplace=True)

# %%
holidays_events.head()
# Out:
#          date  type  locale  locale_name  transferred
# 0  2012-03-02     3       0           15            0
# 1  2012-04-01     3       2            2            0
# 2  2012-04-12     3       0            3            0
# 3  2012-04-14     3       0           12            0
# 4  2012-04-21     3       0           19            0

# %%
print(holidays_events.isnull().sum())
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# transferred    0
# dtype: int64

# %%
holidays_events_dup=holidays_events.duplicated().sum()
holidays_events_dup
# Out:
# 1

# %%
holidays_events['date']=pd.to_datetime(holidays_events['date'] , format= '%Y-%m-%d')

# %%
holidays_events.dtypes
# Out:
# date           datetime64[ns]
# type                    int32
# locale                  int32
# locale_name             int32
# transferred             int32
# dtype: object

# %%
#test.to_csv('Cleaned_Data/cleaned_test.csv', index=False)

# %%
#train.to_csv('Cleaned_Data/cleaned_train.csv', index=False)

# %%
#transactions.to_csv('Cleaned_Data/cleaned_transactions.csv', index=False)

# %%
#stores.to_csv('Cleaned_Data/cleaned_stores.csv', index=False)

# %%
#oil.to_csv('Cleaned_Data/cleaned_oil.csv', index=False)

# %%
#items.to_csv('Cleaned_Data/cleaned_items.csv', index=False)

# %%
#holidayes_events.to_csv('Cleaned_Data/cleaned_holidayes_events.csv', index=False)

# %%
#sample_submission.to_csv('Cleaned_Data/cleaned_sample_submission.csv', index=False)
